# %% [markdown]
# <a href="https://colab.research.google.com/github/lee-hyeon-gu/alpha_python_begin/blob/main/16_%EC%9D%B8%EA%B2%BD%EC%8B%A0%EA%B2%BD%EB%A7%9D%EA%B3%BC_%EB%94%A5%EB%9F%AC%EB%8B%9D_%EB%A7%8C%EB%93%A4%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from tensorflow import keras
from sklearn.preprocessing import StandardScaler

iris=load_iris()
data, target = iris['data'],iris['target']

train_input, test_input, train_target, test_target = train_test_split(data,target)

ss=StandardScaler()
train_scaled = ss.fit_transform(train_input)
test_scaled=ss.transform(test_input)

model=keras.Sequential()
model.add(keras.layers.Dense(5,activation='relu',input_shape=(4,)))
model.add(keras.layers.Dense(3,activation='softmax'))# 1층추가 = 딥러닝
model.compile(loss='sparse_categorical_crossentropy',metrics='accuracy')

hist=model.fit(train_scaled,train_target,epochs=500)
# Out:
# Epoch 1/500
# 4/4 [==============================] - 1s 10ms/step - loss: 1.1013 - accuracy: 0.6518
# Epoch 2/500
# 4/4 [==============================] - 0s 8ms/step - loss: 1.0810 - accuracy: 0.6696
# Epoch 3/500
# 4/4 [==============================] - 0s 5ms/step - loss: 1.0664 - accuracy: 0.6696
# Epoch 4/500
# 4/4 [==============================] - 0s 5ms/step - loss: 1.0541 - accuracy: 0.6696
# Epoch 5/500
# 4/4 [==============================] - 0s 9ms/step - loss: 1.0430 - accuracy: 0.6696
# Epoch 6/500
# 4/4 [==============================] - 0s 8ms/step - loss: 1.0317 - accuracy: 0.6696
# Epoch 7/500
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0209 - accuracy: 0.6696
# Epoch 8/500
# 4/4 [==============================] - 0s 9ms/step - loss: 1.0105 - accuracy: 0.6786
# Epoch 9/500
# 4/4 [==============================] - 0s 8ms/step - loss: 1.0003 - accuracy: 0.6786
# Epoch 10/500
# ...

# %%
import matplotlib.pyplot as plt

plt.plot(hist.history['loss'])

# %%
model.evaluate(test_scaled,test_target)#케라스 평가
# Out:
# 2/2 [==============================] - 0s 12ms/step - loss: 0.2931 - accuracy: 0.9211
# [0.2931272089481354, 0.9210526347160339]
